# %%
import spacy

# %%
nlp = spacy.load('en_core_web_lg')

# %%
google = nlp(u'aeronautical engineer')

# %%
tokens2 = nlp(u' mechanical engineer engineer mechanic')

# %%
tokens.similarity(tokens2)
# Out:
# 0.8186441862375431

# %%
from tornado_fetcher import Fetcher

# %%
fetcher=Fetcher(
  user_agent='Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/69.0.3497.100 Safari/537.36', # user agent
  phantomjs_proxy='http://localhost:1234', # phantomjs url
  pool_size=10, # max httpclient num
  async=False
  )

# %%
url = 'https://www.google.co.in/search?tbm=lcl&q=music+school'
# fetch html after rendering javascript from url
response = fetcher.phantomjs_fetch(url)

# %%
response
# Out:
# {'content': '<!DOCTYPE html><html itemscope="" itemtype="http://schema.org/SearchResultsPage" lang="en-IN" jstcache="0"><head><style type="text/css">.gm-style-pbc{transition:opacity ease-in-out;background-color:rgba(0,0,0,0.45);text-align:center}.gm-style-pbt{font-size:22px;color:white;font-family:Roboto,Arial,sans-serif;position:relative;margin:0;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%)}\n</style><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><meta content="origin" name="referrer"><title>music school - Google Search</title><script src="https://apis.google.com/_/scs/abc-static/_/js/k=gapi.gapi.en.BstDmEhpa_Q.O/m=gapi_iframes,googleapis_client,plusone/rt=j/sv=1/d=1/ed=1/rs=AHpOoo-oqKdOJIcyAi5YyA6pahSkp_ojsw/cb=gapi.loaded_0" nonce="jDWYoBFF7olNgt+FssaXhA==" async=""></script><script nonce="jDWYoBFF7olNgt+FssaXhA==">(function(){window.google={kEI:\'tD3FW9-5BMjbvgT4v6eYCA\',kEXPI:\
# ...

# %%
'Jazzbay' in response['content']
# Out:
# True

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(response['content'])

# %%
[element.get_text() for element in soup.select("div[role=heading]")]
# Out:
# ['Furtados School Of Music',
#  'Furtados Music School in Khar, Mumbai',
#  'Jazzbay Academy of Music',
#  'Strings & Beats Music Institute Ghatkopar',
#  'B-MAD (Bollywood Music Academy & Dance)',
#  'The True School of Music',
#  'DEEPAK MUSIC ACADEMY',
#  'Music Academy',
#  'The Music Gurukul',
#  'Theme Music Institute Juhu',
#  'Tank9 School of Music',
#  'Ajivasan Music Academy',
#  'Beatpro Music Production Courses',
#  'SoundMonk School of Music -Juhu Mumbai',
#  'Anand Music School',
#  'The Music Gurukul',
#  'Shagota Music Academy',
#  'Psalms School of Music',
#  'Theme Music Institute Bandra',
#  'Shree Music Academy']
